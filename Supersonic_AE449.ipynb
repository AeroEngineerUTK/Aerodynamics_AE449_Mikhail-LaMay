# %% [markdown]
# <a href="https://colab.research.google.com/github/AeroEngineerUTK/Aerodynamics_AE449_Mikhail-LaMay/blob/main/Supersonic_AE449.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AE449 - Supersonic Lab Report Data Calculations
# ## Mikhail LaMay - 04/02/2021

# %% [markdown]
# ## Upload Local Github Files to Google Colab
# ___

# %%
# Upload Local Files to Google Colab

# Read the Files w/ Pandas
import io
import pandas as pd
import numpy as np
import math
path = '/content/AE449/'

# pd.set_option('display.max_rows', 3000)
WData = pd.ExcelFile(path +'Test_Wedge_Data.xlsx')            # Locate & Opens Entire Data Sheet
# df1 = pd.read_excel(WData,'Test_1_wedge_2.5')                 # Test #1 - Wedge Data - Mach 2.5
# df2 = pd.read_excel(WData,'Test_2_wedge_3')                   # Test #2 - Wedge Data - Mach 3.0
# df3 = pd.read_excel(WData,'Test_3_wedge_2')                   # Test #3 - Wedge Data - Mach 2.0
# df4 = pd.read_excel(WData,'Test_1_wedge_2.5_Pre_Filtered')    # Test #1 - Pre Filtered Wedge Data - Mach 2.5
# df5 = pd.read_excel(WData,'Test_2_wedge_3_Pre_Filtered')      # Test #2 - Pre Filtered Wedge Data - Mach 3.0
# df6 = pd.read_excel(WData,'Test_1_wedge_2.5_Filtered')        # Test #1 - Fully Filtered Wedge Data - Mach 2.5
# df7 = pd.read_excel(WData,'Test_2_wedge_3_Filtered')          # Test #2 - Fully Filtered Wedge Data - Mach 3.0
df6 = pd.read_excel(WData,'Test1_Other_Data')
df7 = pd.read_excel(WData,'Test2_Other_Data')

WData.sheet_names
# Out:
# ['Test_1_wedge_2.5',
#  'Test_2_wedge_3',
#  'Test_3_wedge_2',
#  'Test_1_wedge_2.5_Pre_Filtered',
#  'Test_1_wedge_2.5_Filtered',
#  'Test_2_wedge_3_Pre_Filtered',
#  'Test_2_wedge_3_Filtered',
#  'Test1_Other_Data',
#  'Test2_Other_Data']

# %% [markdown]
# ## Collect Files From Mikhail's Github
# ___

# %%
# Collect Files from Mikhail's Github

import os

''' Clone github repo to get files '''
if os.path.exists('AE449') == True:
  print('AE449 Folder exists')
else:
  # !git clone https://github.com/AeroEngineerUTK/AE449
# Out:
# AE449 Folder exists

# %% [markdown]
# ## Display Data From Pressure Ports
# ___

# %%
# Test #1 - Fully Filtered Wedge Data - Mach 2.5
display(df6)  # Mach 2.5
display(df7)  # Mach 3.0
# Out:
#        P 1      P 2      P 3      P 4  ...     P 12     P 13     P 14     P 15
# 0  [ psi ]  [ psi ]  [ psi ]  [ psi ]  ...  [ psi ]  [ psi ]  [ psi ]  [ psi ]
# 1  44.4205   14.647  13.8102  4.70975  ...    3.229  3.61175  6.76025  14.3755
#
# [2 rows x 15 columns]
#        P 1      P 2      P 3      P 4  ...     P 12     P 13     P 14     P 15
# 0  [ psi ]  [ psi ]  [ psi ]  [ psi ]  ...  [ psi ]  [ psi ]  [ psi ]  [ psi ]
# 1  69.3649  14.6452  14.3759  4.59063  ...   2.8575  3.55075    5.162  14.3674
#
# [2 rows x 15 columns]

# %% [markdown]
# ## Refine Test 1/2 Data
# ___

# %%
## Test #1 - Mach 2.5 Data Refinement
# Define Stagnation Pressure For Test #1 - Mach 2.5
P1_test1 = df6.iloc[1]['P 1']

# Define Upper Variables For Test #1 - Mach 2.5
P2_test1 = df6.iloc[1]['P 2']
P3_test1 = df6.iloc[1]['P 3']
P4_test1 = df6.iloc[1]['P 4']
P5_test1 = df6.iloc[1]['P 5']
P6_test1 = df6.iloc[1]['P 6']
P7_test1 = df6.iloc[1]['P 7']

# Define Lower Variables For Test #1 - Mach 2.5
P8_test1 = df6.iloc[1]['P 8']
P9_test1 = df6.iloc[1]['P 9']
P10_test1 = df6.iloc[1]['P 10']
P11_test1 = df6.iloc[1]['P 11']
P12_test1 = df6.iloc[1]['P 12']
P13_test1 = df6.iloc[1]['P 13']

# Exit Pressures - 2 Given, Determine Accuracy For Test 1 - Mach 2.5
P14_test1 = df6.iloc[1]['P 14']
P15_test1 = df6.iloc[1]['P 15']

# Create New DataFrame For Test #1 - Mach 2.5
df6_data_corrected = [P1_test1,P2_test1,P3_test1,P4_test1,P5_test1,P6_test1,P7_test1,
                      P8_test1,P9_test1,P10_test1,P11_test1,P12_test1,P13_test1,P14_test1,P15_test1]
df6_corrected = pd.DataFrame(df6_data_corrected, columns = ['Test_1'],
                     index=['Stagnation Pressure (P1)','P2','P3','P4','P5','P6','P7','P8','P9','P10',
                            'P11','P12','P13','Pre-Shock (P14)','Post-Shock (P15)'])
display(df6_corrected)

###############################################################################################################

## Test #2 - Mach 3.0 Data Refinement
# Define Stagnation Pressure For Test #1 - Mach 2.5
P1_test2 = df7.iloc[1]['P 1']

# Define Upper Variables For Test #1 - Mach 2.5
P2_test2 = df7.iloc[1]['P 2']
P3_test2 = df7.iloc[1]['P 3']
P4_test2 = df7.iloc[1]['P 4']
P5_test2 = df7.iloc[1]['P 5']
P6_test2 = df7.iloc[1]['P 6']
P7_test2 = df7.iloc[1]['P 7']

# Define Lower Variables For Test #1 - Mach 2.5
P8_test2 = df7.iloc[1]['P 8']
P9_test2 = df7.iloc[1]['P 9']
P10_test2 = df7.iloc[1]['P 10']
P11_test2 = df7.iloc[1]['P 11']
P12_test2 = df7.iloc[1]['P 12']
P13_test2 = df7.iloc[1]['P 13']

# Exit Pressures - 2 Given, Determine Accuracy For Test 1 - Mach 2.5
P14_test2 = df7.iloc[1]['P 14']
P15_test2 = df7.iloc[1]['P 15']

# Create New DataFrame For Test #1 - Mach 2.5
df7_data_corrected = [P1_test2,P2_test2,P3_test2,P4_test2,P5_test2,P6_test2,P7_test2,
                      P8_test2,P9_test2,P10_test2,P11_test2,P12_test2,P13_test2,P14_test2,P15_test2]
df7_corrected = pd.DataFrame(df7_data_corrected, columns = ['Test_2'],
                     index=['Stagnation Pressure (P1)','P2','P3','P4','P5','P6','P7','P8','P9','P10',
                            'P11','P12','P13','Pre-Shock (P14)','Post-Shock (P15)'])
display(df7_corrected)
# Out:
#                             Test_1
# Stagnation Pressure (P1)  44.42050
# P2                        14.64700
# P3                        13.81025
# P4                         4.70975
# P5                         4.15450
# P6                         3.19550
# P7                         3.52700
# P8                         5.00500
# P9                         3.69825
# P10                        3.24475
# P11                        3.16875
# P12                        3.22900
# P13                        3.61175
# Pre-Shock (P14)            6.76025
# Post-Shock (P15)          14.37550
#                              Test_2
# Stagnation Pressure (P1)  69.364875
# P2                        14.645250
# P3                        14.375875
# P4                         4.590625
# P5                         3.855500
# P6                         2.840500
# P7                         3.124750
# P8                         4.643625
# P9                         3.377625
# ...

# %% [markdown]
# ## Calculating Mach Number Using Pressure Ratio - Test #1
# ___

# %%
gamma = 1.4 # Specific Heat Ratio - Air

# Pressure Ratio - P2/P1
Mach_P2_P1_test1 = (np.sqrt(2) * np.sqrt(df6_corrected.Test_1[0] * (df6_corrected.Test_1[1]/df6_corrected.Test_1[0])**(1/gamma) -
                                   df6_corrected.Test_1[1]))/(np.sqrt(gamma*df6_corrected.Test_1[1] - df6_corrected.Test_1[1]))

# Pressure Ratio - P3/P1
Mach_P3_P1_test1 = (np.sqrt(2) * np.sqrt(df6_corrected.Test_1[0] * (df6_corrected.Test_1[2]/df6_corrected.Test_1[0])**(1/gamma) -
                                   df6_corrected.Test_1[2]))/(np.sqrt(gamma*df6_corrected.Test_1[2] - df6_corrected.Test_1[2]))

# Pressure Ratio - P4/P1
Mach_P4_P1_test1 = (np.sqrt(2) * np.sqrt(df6_corrected.Test_1[0] * (df6_corrected.Test_1[3]/df6_corrected.Test_1[0])**(1/gamma) -
                                   df6_corrected.Test_1[3]))/(np.sqrt(gamma*df6_corrected.Test_1[3] - df6_corrected.Test_1[3]))

# Pressure Ratio - P5/P1
Mach_P5_P1_test1 = (np.sqrt(2) * np.sqrt(df6_corrected.Test_1[0] * (df6_corrected.Test_1[4]/df6_corrected.Test_1[0])**(1/gamma) -
                                   df6_corrected.Test_1[4]))/(np.sqrt(gamma*df6_corrected.Test_1[4] - df6_corrected.Test_1[4]))

# Pressure Ratio - P6/P1
Mach_P6_P1_test1 = (np.sqrt(2) * np.sqrt(df6_corrected.Test_1[0] * (df6_corrected.Test_1[5]/df6_corrected.Test_1[0])**(1/gamma) -
                                   df6_corrected.Test_1[5]))/(np.sqrt(gamma*df6_corrected.Test_1[5] - df6_corrected.Test_1[5]))

# Pressure Ratio - P7/P1
Mach_P7_P1_test1 = (np.sqrt(2) * np.sqrt(df6_corrected.Test_1[0] * (df6_corrected.Test_1[6]/df6_corrected.Test_1[0])**(1/gamma) -
                                   df6_corrected.Test_1[6]))/(np.sqrt(gamma*df6_corrected.Test_1[6] - df6_corrected.Test_1[6]))

# Pressure Ratio - P8/P1
Mach_P8_P1_test1 = (np.sqrt(2) * np.sqrt(df6_corrected.Test_1[0] * (df6_corrected.Test_1[7]/df6_corrected.Test_1[0])**(1/gamma) -
                                   df6_corrected.Test_1[7]))/(np.sqrt(gamma*df6_corrected.Test_1[7] - df6_corrected.Test_1[7]))

# Pressure Ratio - P9/P1
Mach_P9_P1_test1 = (np.sqrt(2) * np.sqrt(df6_corrected.Test_1[0] * (df6_corrected.Test_1[8]/df6_corrected.Test_1[0])**(1/gamma) -
                                   df6_corrected.Test_1[8]))/(np.sqrt(gamma*df6_corrected.Test_1[8] - df6_corrected.Test_1[8]))

# Pressure Ratio - P10/P1
Mach_P10_P1_test1 = (np.sqrt(2) * np.sqrt(df6_corrected.Test_1[0] * (df6_corrected.Test_1[9]/df6_corrected.Test_1[0])**(1/gamma) -
                                   df6_corrected.Test_1[9]))/(np.sqrt(gamma*df6_corrected.Test_1[9] - df6_corrected.Test_1[9]))

# Pressure Ratio - P11/P1
Mach_P11_P1_test1 = (np.sqrt(2) * np.sqrt(df6_corrected.Test_1[0] * (df6_corrected.Test_1[10]/df6_corrected.Test_1[0])**(1/gamma) -
                                   df6_corrected.Test_1[10]))/(np.sqrt(gamma*df6_corrected.Test_1[10] - df6_corrected.Test_1[10]))

# Pressure Ratio - P12/P1
Mach_P12_P1_test1 = (np.sqrt(2) * np.sqrt(df6_corrected.Test_1[0] * (df6_corrected.Test_1[11]/df6_corrected.Test_1[0])**(1/gamma) -
                                   df6_corrected.Test_1[11]))/(np.sqrt(gamma*df6_corrected.Test_1[11] - df6_corrected.Test_1[11]))

# Pressure Ratio - P13/P1
Mach_P13_P1_test1 = (np.sqrt(2) * np.sqrt(df6_corrected.Test_1[0] * (df6_corrected.Test_1[12]/df6_corrected.Test_1[0])**(1/gamma) -
                                   df6_corrected.Test_1[12]))/(np.sqrt(gamma*df6_corrected.Test_1[12] - df6_corrected.Test_1[12]))

# Pressure Ratio - P14/P7
Mach_P14_P7_test1 = (np.sqrt(2) * np.sqrt(df6_corrected.Test_1[13] * (df6_corrected.Test_1[6]/df6_corrected.Test_1[13])**(1/gamma) -
                                   df6_corrected.Test_1[6]))/(np.sqrt(gamma*df6_corrected.Test_1[6] - df6_corrected.Test_1[6]))

# Pressure Ratio - P14/P12
Mach_P14_P12_test1 = (np.sqrt(2) * np.sqrt(df6_corrected.Test_1[13] * (df6_corrected.Test_1[12]/df6_corrected.Test_1[13])**(1/gamma) -
                                   df6_corrected.Test_1[12]))/(np.sqrt(gamma*df6_corrected.Test_1[12] - df6_corrected.Test_1[12]))

# Mach Angle to Mach # - Test 1 - Shock Angle of 29-deg
# WedgeAngle = (18/2)*np.pi/180 # Do Not Include
ShockAngle_test1 = 29*np.pi/180
Mach_Angle_test1 = ShockAngle_test1 # - WedgeAngle
MachFrMachAng_test1 = 1/(np.sin(Mach_Angle_test1))

# Calculate Mach Number @ Throat - Test 1
C_test_1 = 370 # Nozzle Counter Setting for Mach = 2.5
Mach_Throat_1 = -1.887 + 3.242*(10**(-2))*C_test_1 - 9.7483*(10**(-5))*(C_test_1**2) + 1.1269*(10**(-7))*(C_test_1**3)

# Manipulate Mach Number Results to Dataframe - Test #1
Mach_Number_Test1 = [Mach_P2_P1_test1, Mach_P3_P1_test1, Mach_P4_P1_test1, Mach_P5_P1_test1, Mach_P6_P1_test1,
                     Mach_P7_P1_test1, Mach_P8_P1_test1, Mach_P9_P1_test1, Mach_P10_P1_test1, Mach_P11_P1_test1,
                     Mach_P12_P1_test1, Mach_P13_P1_test1, Mach_P14_P7_test1, Mach_P14_P12_test1,
                     MachFrMachAng_test1, Mach_Throat_1]
dfMachNumber_test1 = pd.DataFrame(Mach_Number_Test1, columns = ['Mach # - Test 1 - Mach: 2.5'],
                     index=['P2/P1','P3/P1','P4/P1','P5/P1','P6/P1','P7/P1','P8/P1','P9/P1','P10/P1','P11/P1',
                            'P12/P1','P13/P1','P14/P7','P14/P12','Mach # - Mach Angle', 'Mach # - Throat'])
display(dfMachNumber_test1)


Area_Ratio_test1 = -35.589 + 0.37273*C_test_1 - 1.2422*(10**(-3))*C_test_1**2 + 1.4072*(10**(-6))*C_test_1**3
print(Area_Ratio_test1)
# Out:
#                      Mach # - Test 1 - Mach: 2.5
# P2/P1                                   1.365630
# P3/P1                                   1.407586
# P4/P1                                   2.119771
# P5/P1                                   2.199966
# P6/P1                                   2.367713
# P7/P1                                   2.304590
# P8/P1                                   2.080848
# P9/P1                                   2.274291
# P10/P1                                  2.357926
# P11/P1                                  2.373092
# P12/P1                                  2.361039
# P13/P1                                  2.289415
# P14/P7                                  1.010665
# P14/P12                                 0.990319
# Mach # - Mach Angle                     2.062665
# Mach # - Throat                         2.471064
# 3.5428216000000106

# %% [markdown]
# ## Plot Mach Number Results - Test #1
# ___

# %%
import matplotlib.pyplot as plt

# Creating Mach # Results For Test #1
data_test1 = {'P2/P1': Mach_P2_P1_test1,'P3/P1': Mach_P3_P1_test1,'P4/P1': Mach_P4_P1_test1,'P5/P1': Mach_P5_P1_test1,'P6/P1': Mach_P6_P1_test1,
        'P7/P1': Mach_P7_P1_test1,'P8/P1': Mach_P8_P1_test1,'P9/P1': Mach_P9_P1_test1,'P10/P1': Mach_P10_P1_test1,'P11/P1': Mach_P11_P1_test1,
        'P12/P1': Mach_P12_P1_test1,'P13/P1': Mach_P13_P1_test1,'P14/P7': Mach_P14_P7_test1,'P14/P12': Mach_P14_P12_test1}
names_test1 = list(data_test1.keys())
values_test1 = list(data_test1.values())

# plt.figure(figsize=(10,5))                                                  # Setting Figure Size
# plt.title('Mach Number Results: Test #1 - Mach 2.5', fontsize = 20)         # Adding Title
# plt.xlabel('Pressure Ratios', fontsize=15)                                  # X Axis Name
# plt.ylabel('Mach Number', fontsize=15)                                      # Y Axis Name
# plt.rcParams['font.size'] = '12'                                            # Setting Axis Font Size
# plt.grid()                                                                  # Adding Grid
# axes = plt.gca()
# axes.set_ylim([0.5,2.5])                                                    # Y Axis Range
# plt.xticks(rotation=45)

# plt.style.use(['default'])

# plt.plot(names_test1,values_test1, 'orange')                                   # Changing Line Color

# %% [markdown]
# ## Calculating Mach Number Using Pressure Ratio - Test #2
# ___

# %%
gamma = 1.4 # Specific Heat Ratio - Air

# Pressure Ratio - P2/P1
Mach_P2_P1_test2 = (np.sqrt(2) * np.sqrt(df7_corrected.Test_2[0] * (df7_corrected.Test_2[1]/df7_corrected.Test_2[0])**(1/gamma) -
                                   df7_corrected.Test_2[1]))/(np.sqrt(gamma*df7_corrected.Test_2[1] - df7_corrected.Test_2[1]))

# Pressure Ratio - P3/P1
Mach_P3_P1_test2 = (np.sqrt(2) * np.sqrt(df7_corrected.Test_2[0] * (df7_corrected.Test_2[2]/df7_corrected.Test_2[0])**(1/gamma) -
                                   df7_corrected.Test_2[2]))/(np.sqrt(gamma*df7_corrected.Test_2[2] - df7_corrected.Test_2[2]))

# Pressure Ratio - P4/P1
Mach_P4_P1_test2 = (np.sqrt(2) * np.sqrt(df7_corrected.Test_2[0] * (df7_corrected.Test_2[3]/df7_corrected.Test_2[0])**(1/gamma) -
                                   df7_corrected.Test_2[3]))/(np.sqrt(gamma*df7_corrected.Test_2[3] - df7_corrected.Test_2[3]))

# Pressure Ratio - P5/P1
Mach_P5_P1_test2 = (np.sqrt(2) * np.sqrt(df7_corrected.Test_2[0] * (df7_corrected.Test_2[4]/df7_corrected.Test_2[0])**(1/gamma) -
                                   df7_corrected.Test_2[4]))/(np.sqrt(gamma*df7_corrected.Test_2[4] - df7_corrected.Test_2[4]))

# Pressure Ratio - P6/P1
Mach_P6_P1_test2 = (np.sqrt(2) * np.sqrt(df7_corrected.Test_2[0] * (df7_corrected.Test_2[5]/df7_corrected.Test_2[0])**(1/gamma) -
                                   df7_corrected.Test_2[5]))/(np.sqrt(gamma*df7_corrected.Test_2[5] - df7_corrected.Test_2[5]))

# Pressure Ratio - P7/P1
Mach_P7_P1_test2 = (np.sqrt(2) * np.sqrt(df7_corrected.Test_2[0] * (df7_corrected.Test_2[6]/df7_corrected.Test_2[0])**(1/gamma) -
                                   df7_corrected.Test_2[6]))/(np.sqrt(gamma*df7_corrected.Test_2[6] - df7_corrected.Test_2[6]))

# Pressure Ratio - P8/P1
Mach_P8_P1_test2 = (np.sqrt(2) * np.sqrt(df7_corrected.Test_2[0] * (df7_corrected.Test_2[7]/df7_corrected.Test_2[0])**(1/gamma) -
                                   df7_corrected.Test_2[7]))/(np.sqrt(gamma*df7_corrected.Test_2[7] - df7_corrected.Test_2[7]))

# Pressure Ratio - P9/P1
Mach_P9_P1_test2 = (np.sqrt(2) * np.sqrt(df7_corrected.Test_2[0] * (df7_corrected.Test_2[8]/df7_corrected.Test_2[0])**(1/gamma) -
                                   df7_corrected.Test_2[8]))/(np.sqrt(gamma*df7_corrected.Test_2[8] - df7_corrected.Test_2[8]))

# Pressure Ratio - P10/P1
Mach_P10_P1_test2 = (np.sqrt(2) * np.sqrt(df7_corrected.Test_2[0] * (df7_corrected.Test_2[9]/df7_corrected.Test_2[0])**(1/gamma) -
                                   df7_corrected.Test_2[9]))/(np.sqrt(gamma*df7_corrected.Test_2[9] - df7_corrected.Test_2[9]))

# Pressure Ratio - P11/P1
Mach_P11_P1_test2 = (np.sqrt(2) * np.sqrt(df7_corrected.Test_2[0] * (df7_corrected.Test_2[10]/df7_corrected.Test_2[0])**(1/gamma) -
                                   df7_corrected.Test_2[10]))/(np.sqrt(gamma*df7_corrected.Test_2[10] - df7_corrected.Test_2[10]))

# Pressure Ratio - P12/P1
Mach_P12_P1_test2 = (np.sqrt(2) * np.sqrt(df7_corrected.Test_2[0] * (df7_corrected.Test_2[11]/df7_corrected.Test_2[0])**(1/gamma) -
                                   df7_corrected.Test_2[11]))/(np.sqrt(gamma*df7_corrected.Test_2[11] - df7_corrected.Test_2[11]))

# Pressure Ratio - P13/P1
Mach_P13_P1_test2 = (np.sqrt(2) * np.sqrt(df7_corrected.Test_2[0] * (df7_corrected.Test_2[12]/df7_corrected.Test_2[0])**(1/gamma) -
                                   df7_corrected.Test_2[12]))/(np.sqrt(gamma*df7_corrected.Test_2[12] - df7_corrected.Test_2[12]))

# Pressure Ratio - P14/P7
Mach_P14_P7_test2 = (np.sqrt(2) * np.sqrt(df7_corrected.Test_2[13] * (df7_corrected.Test_2[6]/df7_corrected.Test_2[13])**(1/gamma) -
                                   df7_corrected.Test_2[6]))/(np.sqrt(gamma*df7_corrected.Test_2[6] - df7_corrected.Test_2[6]))

# Pressure Ratio - P14/P12
Mach_P14_P12_test2 = (np.sqrt(2) * np.sqrt(df7_corrected.Test_2[13] * (df7_corrected.Test_2[12]/df7_corrected.Test_2[13])**(1/gamma) -
                                   df7_corrected.Test_2[12]))/(np.sqrt(gamma*df7_corrected.Test_2[12] - df7_corrected.Test_2[12]))

# Mach Angle to Mach # - Test 2 - Shock Angle of 25-deg
# WedgeAngle = (18/2)*np.pi/180
ShockAngle_test2 = 25*np.pi/180
Mach_Angle_test2 = ShockAngle_test2 # - WedgeAngle
MachFrMachAng_test2 = 1/(np.sin(Mach_Angle_test2))

# Calculate Mach Number @ Throat - Test 2
C_test_2 = 431 # Nozzle Counter Setting for Mach = 3.0
Mach_Throat_2 = -1.887 + 3.242*(10**(-2))*C_test_2 - 9.7483*(10**(-5))*(C_test_2**2) + 1.1269*(10**(-7))*(C_test_2**3)

# Manipulate Mach Number Results to Dataframe - Test #1
Mach_Number_test2 = [Mach_P2_P1_test2, Mach_P3_P1_test2, Mach_P4_P1_test2, Mach_P5_P1_test2, Mach_P6_P1_test2,
                     Mach_P7_P1_test2, Mach_P8_P1_test2, Mach_P9_P1_test2, Mach_P10_P1_test2,Mach_P11_P1_test2,
                     Mach_P12_P1_test2, Mach_P13_P1_test2, Mach_P14_P7_test2, Mach_P14_P12_test2,
                     MachFrMachAng_test2, Mach_Throat_2]
dfMachNumber_test2 = pd.DataFrame(Mach_Number_test2, columns = ['Mach # - Test 2 - Mach: 3.0'],
                     index=['P2/P1','P3/P1','P4/P1','P5/P1','P6/P1','P7/P1','P8/P1','P9/P1','P10/P1','P11/P1',
                            'P12/P1','P13/P1','P14/P7','P14/P12','Mach # - Mach Angle', 'Mach # - Throat'])
display(dfMachNumber_test2)

Area_Ratio_test2 = -35.589 + 0.37273*C_test_2 - 1.2422*(10**(-3))*C_test_2**2 + 1.4072*(10**(-6))*C_test_2**3
print(Area_Ratio_test2)
# Out:
#                      Mach # - Test 2 - Mach: 3.0
# P2/P1                                   1.672564
# P3/P1                                   1.684915
# P4/P1                                   2.421125
# P5/P1                                   2.533212
# P6/P1                                   2.731040
# P7/P1                                   2.669020
# P8/P1                                   2.413769
# P9/P1                                   2.618604
# P10/P1                                  2.722382
# P11/P1                                  2.745195
# P12/P1                                  2.727152
# P13/P1                                  2.586301
# P14/P7                                  0.878107
# P14/P12                                 0.751092
# Mach # - Mach Angle                     2.366202
# Mach # - Throat                         2.999779
# 6.9699567352

# %% [markdown]
# ## Plot Mach Number Results - Test #2
# ___

# %%
import matplotlib.pyplot as plt

# Creating Mach # Results For Test #2
data_test2 = {'P2/P1': Mach_P2_P1_test2,'P3/P1': Mach_P3_P1_test2,'P4/P1': Mach_P4_P1_test2,'P5/P1': Mach_P5_P1_test2,'P6/P1': Mach_P6_P1_test2,
        'P7/P1': Mach_P7_P1_test2,'P8/P1': Mach_P8_P1_test2,'P9/P1': Mach_P9_P1_test2,'P10/P1': Mach_P10_P1_test2,'P11/P1': Mach_P11_P1_test2,
        'P12/P1': Mach_P12_P1_test2,'P13/P1': Mach_P13_P1_test2,'P14/P7': Mach_P14_P7_test2,'P14/P12': Mach_P14_P12_test2}
names_test2 = list(data_test2.keys())
values_test2 = list(data_test2.values())

plt.figure(figsize=(14,5))                                                  # Setting Figure Size
# plt.title('Mach Number Results: Test #2 - Mach 3.0', fontsize = 20)         # Adding Title
plt.xlabel('Pressure Ratios', fontsize=15)                                  # X Axis Name
plt.ylabel('Mach Number', fontsize=15)                                      # Y Axis Name
plt.rcParams['font.size'] = '12'                                            # Setting Axis Font Size
plt.grid()                                                                  # Adding Grid
axes = plt.gca()
axes.set_ylim([0.5,3.0])                                                    # Y Axis Range
plt.xticks(rotation=15)

plt.plot(names_test1,values_test1, 'blue', label = 'Test 1 - Mach 2.5')                                   # Changing Line Color
plt.plot(names_test2,values_test2, 'red', label = 'Test 2 - Mach 3.0')                                   # Changing Line Color

leg = axes.legend()
